# %% [markdown]
# #instalar o pandas e importa-lo
# !pip install pandas -- (como já está instalado, não há necessidade de instalar.)

# %%
import pandas as pd

# %%
lista = ["Patrícia", "Camila", "Gabi", "Anna", "Tamires"]

serie_da_lista = pd.Series(lista)
print(serie_da_lista)
type(serie_da_lista)
# Out:
# 0    Patrícia
# 1      Camila
# 2        Gabi
# 3        Anna
# 4     Tamires
# dtype: object
# pandas.core.series.Series

# %%
dicionario = {"a": "Patrícia", "b": "Camila", "c": "Gabi", "d": "Anna", "e": "Tamires"}

serie_do_dicionario = pd.Series(dicionario)
print(serie_do_dicionario)
type(serie_do_dicionario)
# Out:
# a    Patrícia
# b      Camila
# c        Gabi
# d        Anna
# e     Tamires
# dtype: object
# pandas.core.series.Series

# %%
import numpy as np

# %%
array_numpy = np.random.randint(5, 25, size=5)
print(array_numpy)

serie_do_array = pd.Series(array_numpy)

serie_do_array
# type(serie_do_array)
# Out:
# [24 17 19 17  6]
# 0    24
# 1    17
# 2    19
# 3    17
# 4     6
# dtype: int32

# %%
serie_do_dicionario[0]
# Out:
# C:\Users\stefa\AppData\Local\Temp\ipykernel_7824\3066844099.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   serie_do_dicionario[0]
# 'Patrícia'

# %%
serie_do_dicionario["d"]
# Out:
# 'Anna'

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId                                          Name   Age  \
# 0            892                              Kelly, Mr. James  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2            894                     Myles, Mr. Thomas Francis  62.0
# 3            895                              Wirz, Mr. Albert  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..           ...                                           ...   ...
# 413         1305                            Spector, Mr. Woolf   NaN
# 414         1306                  Oliva y Ocana, Dona. Fermina  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen  38.5
# 416         1308                           Ware, Mr. Frederick   NaN
# 417         1309                      Peter, Master. Michael J   NaN
#
#                  Ticket     Fare Cabin Embarked
# 0                330911   7.8292   NaN        Q
# ...

# %%
df.head()
# Out:
#    PassengerId                                          Name   Age   Ticket  \
# 0          892                              Kelly, Mr. James  34.5   330911
# 1          893              Wilkes, Mrs. James (Ellen Needs)  47.0   363272
# 2          894                     Myles, Mr. Thomas Francis  62.0   240276
# 3          895                              Wirz, Mr. Albert  27.0   315154
# 4          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0  3101298
#
#       Fare Cabin Embarked
# 0   7.8292   NaN        Q
# 1        7   NaN        S
# 2   9.6875   NaN        Q
# 3   8.6625   NaN        S
# 4  12.2875   NaN        S

# %%
#ele mostra as ultimas linhas
df.tail()
# Out:
#      PassengerId                          Name   Age              Ticket  \
# 413         1305            Spector, Mr. Woolf   NaN           A.5. 3236
# 414         1306  Oliva y Ocana, Dona. Fermina  39.0            PC 17758
# 415         1307  Saether, Mr. Simon Sivertsen  38.5  SOTON/O.Q. 3101262
# 416         1308           Ware, Mr. Frederick   NaN              359309
# 417         1309      Peter, Master. Michael J   NaN                2668
#
#         Fare Cabin Embarked
# 413    08.05   NaN        S
# 414    108.9  C105        C
# 415     7.25   NaN        S
# 416    08.05   NaN        S
# 417  223.583   NaN        C

# %%
#qual é tamanho do dataframe
df.shape
# Out:
# (418, 7)

# %%
#resumo estatístico
df.describe()
# Out:
#        PassengerId         Age
# count   418.000000  332.000000
# mean   1100.500000   30.272590
# std     120.810458   14.181209
# min     892.000000    0.170000
# 25%     996.250000   21.000000
# 50%    1100.500000   27.000000
# 75%    1204.750000   39.000000
# max    1309.000000   76.000000

# %%
#quais são os tipos dos dados?
df.dtypes
# Out:
# PassengerId      int64
# Name            object
# Age            float64
# Ticket          object
# Fare            object
# Cabin           object
# Embarked        object
# dtype: object

# %%
#reduzir o número de amostras, podemos usar a função sample
#de uma maneira aleatoria
df_menor = df.sample(250)
df_menor.shape
# Out:
# (250, 7)

# %%
#resetar o index que mostra anteriormente de forma aleatoria para um ordem crescente
#drop ele apaga o a coluna primeira sozinho 
df_menor = df_menor.reset_index(drop=True)
df_menor
# Out:
#      PassengerId                                               Name   Age  \
# 0           1022                            Spinner, Mr. Henry John  32.0
# 1           1150                            Bentham, Miss. Lilian W  19.0
# 2            918                       Ostby, Miss. Helene Ragnhild  22.0
# 3           1227                           Maguire, Mr. John Edward  30.0
# 4           1042              Earnshaw, Mrs. Boulton (Olive Potter)  23.0
# ..           ...                                                ...   ...
# 245          955                       Bradley, Miss. Bridget Delia  22.0
# 246          982  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...  22.0
# 247          900          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0
# 248         1220                      Clarke, Mr. Charles Valentine  29.0
# 249         1254       Ware, Mrs. John James (Florence Louise Long)  31.0
#
#               Ticket     Fare Cabin Embarked
# ...

# %%
#ele mostra o invervalo que você quer dentor da amostra poendo colocar o coemço e  fim; 

df[:250]
# Out:
#      PassengerId                                          Name   Age  \
# 0            892                              Kelly, Mr. James  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2            894                     Myles, Mr. Thomas Francis  62.0
# 3            895                              Wirz, Mr. Albert  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..           ...                                           ...   ...
# 245         1137                       Kenyon, Mr. Frederick R  41.0
# 246         1138         Karnes, Mrs. J Frank (Claire Bennett)  22.0
# 247         1139                        Drew, Mr. James Vivian  42.0
# 248         1140      Hold, Mrs. Stephen (Annie Margaret Hill)  29.0
# 249         1141     Khalil, Mrs. Betros (Zahie Maria" Elias)"   NaN
#
#            Ticket     Fare Cabin Embarked
# 0          330911   7.8292   NaN        Q
# 1          363272        7   NaN        S
# ...

# %%
#ele mostra que recebe essa informação
df_menor_organizado = df[:250]

# %%
#ele conta quantas linhas nulas temos; 
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Age             86
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#mudar uma coluna com o tipo
df_menor_organizado['Age'].astype(int)
df_menor_organizado.head(5)

# %%
#exercicios
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_exercicios = df[:50]
df_exercicios.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_exercicios.shape
# Out:
# (50, 12)

# %%
df_exercicios = df_exercicios.dropna(subset=['Cabin'])
df_exercicios.shape
# Out:
# (9, 12)

# %%
df_exercicios['Age'] = df_exercicios['Age'].fillna(df_exercicios['Age'].mean())

# %%
df_exercicios.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 31           32         1       1
#
#                                                  Name     Sex    Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 6                             McCarthy, Mr. Timothy J    male  54.00      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 11                           Bonnell, Miss. Elizabeth  female  58.00      0
# 21                              Beesley, Mr. Lawrence    male  34.00      0
# 23                       Sloper, Mr. William Thompson    male  28.00      0
# ...
