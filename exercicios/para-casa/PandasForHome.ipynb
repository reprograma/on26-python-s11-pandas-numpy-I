# %%
import pandas as pd
df = pd.read_csv("songs.csv")
df
# Out:
#                school                                          song_name  \
# 0          Notre Dame                                      Victory March
# 1              Baylor                                          Old Fight
# 2          Iowa State                                  Iowa State Fights
# 3              Kansas                                      I'm a Jayhawk
# 4        Kansas State                                    Wildcat Victory
# 5            Oklahoma                                      Boomer Sooner
# 6      Oklahoma State                                   Ride 'Em Cowboys
# 7               Texas                                        Texas Fight
# 8                 TCU                                     TCU Fight Song
# 9          Texas Tech                              Fight, Raiders, Fight
# 10      West Virginia                                 Hail West Virginia
# 11           Illinois                                      Oskee-Wow-Wow
# ...

# %%
df_teste = pd.read_csv("songs.csv")
df_teste
# Out:
#                school                                          song_name  \
# 0          Notre Dame                                      Victory March
# 1              Baylor                                          Old Fight
# 2          Iowa State                                  Iowa State Fights
# 3              Kansas                                      I'm a Jayhawk
# 4        Kansas State                                    Wildcat Victory
# 5            Oklahoma                                      Boomer Sooner
# 6      Oklahoma State                                   Ride 'Em Cowboys
# 7               Texas                                        Texas Fight
# 8                 TCU                                     TCU Fight Song
# 9          Texas Tech                              Fight, Raiders, Fight
# 10      West Virginia                                 Hail West Virginia
# 11           Illinois                                      Oskee-Wow-Wow
# ...

# %%
df_teste.head(3)
# Out:
#        school          song_name  \
# 0  Notre Dame      Victory March
# 1      Baylor          Old Fight
# 2  Iowa State  Iowa State Fights
#
#                                              writers  year official_song  \
# 0                   Michael J. Shea and John F. Shea  1908           Yes
# 1                         Dick Baker and Frank Boggs  1947           Yes
# 2  Jack Barker, Manly Rice, Paul Gnam, Rosalind K...  1930           Yes
#
#    sec_duration fight victory colors opponents spelling  trope_count  \
# 0            64   Yes     Yes    Yes        No       No            6
# 1            99   Yes     Yes    Yes        No      Yes            5
# 2            55   Yes      No     No        No      Yes            4
#
#                spotify_id
# 0  15a3ShKX3XWKzq0lSS48yr
# 1  2ZsaI0Cu4nz8DHfBkPt0Dl
# 2  3yyfoOXZQCtR6pfRJqu9pl

# %%
df_teste.columns
# Out:
# Index(['school', 'song_name', 'writers', 'year', 'official_song',
#        'sec_duration', 'fight', 'victory', 'colors', 'opponents', 'spelling',
#        'trope_count', 'spotify_id'],
#       dtype='object')

# %%
df_teste.drop(columns=["school"])
# Out:
#                                             song_name  \
# 0                                       Victory March
# 1                                           Old Fight
# 2                                   Iowa State Fights
# 3                                       I'm a Jayhawk
# 4                                     Wildcat Victory
# 5                                       Boomer Sooner
# 6                                    Ride 'Em Cowboys
# 7                                         Texas Fight
# 8                                      TCU Fight Song
# 9                               Fight, Raiders, Fight
# 10                                 Hail West Virginia
# 11                                      Oskee-Wow-Wow
# 12                               Indiana, Our Indiana
# 13                                    Iowa Fight Song
# 14                                Maryland Fight Song
# 15                                        The Victors
# ...

# %%
df_teste.dropna(inplace=True)

# %%
df_teste.isnull().sum()
# Out:
# school           0
# song_name        0
# writers          0
# year             0
# official_song    0
# sec_duration     0
# fight            0
# victory          0
# colors           0
# opponents        0
# spelling         0
# trope_count      0
# spotify_id       0
# dtype: int64

# %%
df_teste = df_teste.dropna(subset=["school", "song_name", "writers", "year", "official_song", "sec_duration", "fight", "victory", "colors", "opponents", "spelling", "trope_count", "spotify_id"])

# %%
df_teste = df_teste.reset_index(drop=True)
df_teste
# Out:
#                school                                          song_name  \
# 0          Notre Dame                                      Victory March
# 1              Baylor                                          Old Fight
# 2          Iowa State                                  Iowa State Fights
# 3              Kansas                                      I'm a Jayhawk
# 4        Kansas State                                    Wildcat Victory
# 5            Oklahoma                                      Boomer Sooner
# 6      Oklahoma State                                   Ride 'Em Cowboys
# 7               Texas                                        Texas Fight
# 8                 TCU                                     TCU Fight Song
# 9          Texas Tech                              Fight, Raiders, Fight
# 10      West Virginia                                 Hail West Virginia
# 11           Illinois                                      Oskee-Wow-Wow
# ...

# %% [markdown]
# # INSIGHT : Se for possível adicionar um portifólio da música com imagem.

# %% [markdown]
# # INSIGHT: Além da lista criar uma sublista com informações do artistas para serem pesquisadas como forma de input.

# %% [markdown]
# Não sei se entendi muito bem sobre os insights, me perdoe. <3
