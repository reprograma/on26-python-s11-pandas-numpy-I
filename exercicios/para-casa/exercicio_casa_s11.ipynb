# %%
import pandas as pd

# %% [markdown]
# - INTRODUÇÃO
# Esta base de dados contém elementos sobre Os vingadores(Marvel). Nela podemos encontrar informações como nome completo do personagem, 1ª aparição em HQ e links oficiais.

# %%
df = pd.read_csv("avengers.csv")
df
# Out:
#                                                   URL  \
# 0       http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1   http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2   http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3   http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4    http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5   http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6   http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7    http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8   http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9   http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10  http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 11       http://marvel.wikia.com/Hercules_(Earth-616)
# 12     http://marvel.wikia.com/T%27Challa_(Earth-616)
# 13         http://marvel.wikia.com/Vision_(Earth-616)
#
#                            Name  Appearances Current  Gender Full Intro  Year  \
# ...

# %%
df.dtypes
# Out:
# URL                    object
# Name                   object
# Appearances             int64
# Current                object
# Gender                 object
# Full Intro             object
# Year                    int64
# Years since joining     int64
# Notes                  object
# dtype: object

# %%
df.head(3)
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
#
#                           Name  Appearances Current  Gender Full Intro  Year  \
# 0    Henry Jonathan "Hank" Pym         1269     YES    MALE     Sep-63  1963
# 1               Janet van Dyne         1165     YES  FEMALE     Sep-63  1963
# 2  Anthony Edward "Tony" Stark         3068     YES    MALE     Sep-63  1963
#
#    Years since joining                                              Notes
# 0                   52  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1                   52  Dies in Secret Invasion V1:I8. Actually was se...
# 2                   52  Death: "Later while under the influence of Imm...

# %%
df.shape
# Out:
# (14, 9)

# %%
df.columns
# Out:
# Index(['URL', 'Name', 'Appearances', 'Current', 'Gender', 'Full Intro', 'Year',
#        'Years since joining', 'Notes'],
#       dtype='object')

# %%
df_limpo = df
df_limpo
# Out:
#                                                   URL  \
# 0       http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1   http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2   http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3   http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4    http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5   http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6   http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7    http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8   http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9   http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10  http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 11       http://marvel.wikia.com/Hercules_(Earth-616)
# 12     http://marvel.wikia.com/T%27Challa_(Earth-616)
# 13         http://marvel.wikia.com/Vision_(Earth-616)
#
#                            Name  Appearances Current  Gender Full Intro  Year  \
# ...

# %%
df_limpo.isnull().sum()
# Out:
# URL                    0
# Name                   0
# Appearances            0
# Current                0
# Gender                 0
# Full Intro             0
# Year                   0
# Years since joining    0
# Notes                  3
# dtype: int64

# %%
df_limpo = df_limpo.dropna(subset=["Notes"])
df_limpo.shape
# Out:
# (11, 9)

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   URL                  11 non-null     object
#  1   Name                 11 non-null     object
#  2   Appearances          11 non-null     int64
#  3   Current              11 non-null     object
#  4   Gender               11 non-null     object
#  5   Full Intro           11 non-null     object
#  6   Year                 11 non-null     int64
#  7   Years since joining  11 non-null     int64
#  8   Notes                11 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 880.0+ bytes

# %%
df_limpo.columns
# Out:
# Index(['URL', 'Name', 'Appearances', 'Current', 'Gender', 'Full Intro', 'Year',
#        'Years since joining', 'Notes'],
#       dtype='object')

# %%
df_limpo.drop(columns=["Year"])
# Out:
#                                                   URL  \
# 0       http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1   http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2   http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3   http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4    http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 6   http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7    http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8   http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9   http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10  http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 13         http://marvel.wikia.com/Vision_(Earth-616)
#
#                            Name  Appearances Current  Gender Full Intro  \
# 0     Henry Jonathan "Hank" Pym         1269     YES    MALE     Sep-63
# 1                Janet van Dyne         1165     YES  FEMALE     Sep-63
# 2   Anthony Edward "Tony" Stark         3068     YES    MALE     Sep-63
# ...

# %%
df_limpo.info()
df_limpo.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   URL                  11 non-null     object
#  1   Name                 11 non-null     object
#  2   Appearances          11 non-null     int64
#  3   Current              11 non-null     object
#  4   Gender               11 non-null     object
#  5   Full Intro           11 non-null     object
#  6   Year                 11 non-null     int64
#  7   Years since joining  11 non-null     int64
#  8   Notes                11 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 880.0+ bytes
# (11, 9)

# %%
""" df.loc[df['Name'] == 'Name'] = 'Nome'
df.dropna(inplace = True)
df 
Não pegou, vou analisar melhor depois. Favor desconsiderar!"""
# Out:
#                                                   URL  \
# 0       http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1   http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2   http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3   http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4    http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 6   http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7    http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8   http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9   http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10  http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 13         http://marvel.wikia.com/Vision_(Earth-616)
#
#                            Name  Appearances Current  Gender Full Intro  Year  \
# 0     Henry Jonathan "Hank" Pym         1269     YES    MALE     Sep-63  1963
# 1                Janet van Dyne         1165     YES  FEMALE     Sep-63  1963
# 2   Anthony Edward "Tony" Stark         3068     YES    MALE     Sep-63  1963
# ...
