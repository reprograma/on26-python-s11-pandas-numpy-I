# %% [markdown]
# ### Introdução
# A base de dados disponibilizada tem como base o incidente do Titanic, seus dados são compostos por uma ID para cada passageiro, status de sobrevivência em valor booleano (0 - morto e 1 - vivo), tipo de passagem, nome, sexo biológico, idade, ticket, valor pago, cabine e tipo de embarque.
# Obs: os dados "SibSp" e "Parch" são foram possiveís de serem identificados.

# %% [markdown]
# ### Processamento

# %%
import pandas as pd
import numpy as np
import csv

# %%
#Carregar dataframe
df = pd.read_csv('titanic.csv')

# %%
#Verificar características da base
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Ler as três primeiras linhas
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#Tradução de colunas
df.rename(columns={'PassengerId': 'ID Passageiro', 'Survived': 'Sobrevivente', 'Pclass': 'Classe', 'Name': 'Nome/Sobrenome', 'Sex': 'Sexo Biológico', 'Age': 'Idade', 'SibSp': 'Sib', 'Parch': 'Passe', 'Ticket': 'Passagem', 'Fare': 'Valor da Passagem', 'Cabin': 'Cabine', 'Embarked': "Embarque"}, inplace = True)

# %%
#Ler a primeira linha (cabeçalho)
df.head(0)
# Out:
# Empty DataFrame
# Columns: [ID Passageiro, Sobrevivente, Classe, Nome/Sobrenome, Sexo Biológico, Idade, Sib, Passe, Passagem, Valor da Passagem, Cabine, Embarque]
# Index: []

# %%
#Atualização de nome F e M
df['Sexo Biológico'] = df['Sexo Biológico'].replace({'male': 'M', 'female': 'F'})

# %%
#Deleção de colunas
df = df.drop(columns=['Sib', 'Passe'])
df
# Out:
#      ID Passageiro  Sobrevivente  Classe  \
# 0                1             0       3
# 1                2             1       1
# 2                3             1       3
# 3                4             1       1
# 4                5             0       3
# ..             ...           ...     ...
# 886            887             0       2
# 887            888             1       1
# 888            889             0       3
# 889            890             1       1
# 890            891             0       3
#
#                                         Nome/Sobrenome Sexo Biológico  Idade  \
# 0                              Braund, Mr. Owen Harris              M   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...              F   38.0
# 2                               Heikkinen, Miss. Laina              F   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)              F   35.0
# 4                             Allen, Mr. William Henry              M   35.0
# ..                                                 ...            ...    ...
# 886                              Montvila, Rev. Juozas              M   27.0
# 887                       Graham, Miss. Margaret Edith              F   19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"              F    NaN
# 889                              Behr, Mr. Karl Howell              M   26.0
# 890                                Dooley, Mr. Patrick              M   32.0
#
#              Passagem  Valor da Passagem Cabine Embarque
# 0           A/5 21171             7.2500    NaN        S
# 1            PC 17599            71.2833    C85        C
# 2    STON/O2. 3101282             7.9250    NaN        S
# 3              113803            53.1000   C123        S
# 4              373450             8.0500    NaN        S
# ..                ...                ...    ...      ...
# 886            211536            13.0000    NaN        S
# 887            112053            30.0000    B42        S
# 888        W./C. 6607            23.4500    NaN        S
# 889            111369            30.0000   C148        C
# 890            370376             7.7500    NaN        Q
#
# [891 rows x 10 columns]

# %%
#Verifica se há valores nulos
print("Valores nulos por coluna do dataframe:")
print(df.isnull().sum())
# Out:
# Valores nulos por coluna do dataframe:
# ID Passageiro          0
# Sobrevivente           0
# Classe                 0
# Nome/Sobrenome         0
# Sexo Biológico         0
# Idade                177
# Passagem               0
# Valor da Passagem      0
# Cabine               687
# Embarque               2
# dtype: int64

# %%
#Preenche valores nulos da coluna Idade, Cabine e Embarque
df['Idade'] = df['Idade'].fillna('N/A')
df['Cabine'] = df['Cabine'].fillna('N/A')
df['Embrque'] = df['Embarque'].fillna('N/A')

# %%
#Remove nulos em colunas específicas
df = df.dropna(subset=['Idade', 'Cabine', 'Embarque'])
df.shape
# Out:
# (889, 11)

# %%
#Sort de valores
df.sort_values(by='Sobrevivente')
# Out:
#      ID Passageiro  Sobrevivente  Classe                     Nome/Sobrenome  \
# 0                1             0       3            Braund, Mr. Owen Harris
# 519            520             0       3                Pavlovic, Mr. Stefo
# 521            522             0       3                    Vovk, Mr. Janko
# 522            523             0       3                 Lahoud, Mr. Sarkis
# 524            525             0       3                  Kassem, Mr. Fared
# ..             ...           ...     ...                                ...
# 547            548             1       2         Padro y Manent, Mr. Julian
# 546            547             1       2  Beane, Mrs. Edward (Ethel Clarke)
# 216            217             1       3             Honkanen, Miss. Eliina
# 218            219             1       1              Bazzani, Miss. Albina
# 445            446             1       1          Dodge, Master. Washington
#
#     Sexo Biológico Idade          Passagem  Valor da Passagem Cabine Embarque  \
# 0                M  22.0         A/5 21171             7.2500    N/A        S
# 519              M  32.0            349242             7.8958    N/A        S
# 521              M  22.0            349252             7.8958    N/A        S
# 522              M   N/A              2624             7.2250    N/A        C
# 524              M   N/A              2700             7.2292    N/A        C
# ..             ...   ...               ...                ...    ...      ...
# 547              M   N/A     SC/PARIS 2146            13.8625    N/A        C
# 546              F  19.0              2908            26.0000    N/A        S
# 216              F  27.0  STON/O2. 3101283             7.9250    N/A        S
# 218              F  32.0             11813            76.2917    D15        C
# 445              M   4.0             33638            81.8583    A34        S
#
#     Embrque
# 0         S
# 519       S
# 521       S
# 522       C
# 524       C
# ..      ...
# 547       C
# 546       S
# 216       S
# 218       C
# 445       S
#
# [889 rows x 11 columns]

# %%
#Lista colunas
df.columns
# Out:
# Index(['ID Passageiro', 'Sobrevivente', 'Classe', 'Nome/Sobrenome',
#        'Sexo Biológico', 'Idade', 'Passagem', 'Valor da Passagem', 'Cabine',
#        'Embarque', 'Embrque'],
#       dtype='object')

# %%
#Copia dataframe original
df.copy()

# %%
#Reset index
df.reset_index(drop=True)

# %%
#Exportar DF para csv
df.to_csv("Base_Titanic")

# %%
#Dados com apresentação  estatísticas descritivas, como média, desvio padrão, máximo, mínimo e outras tendências centrais, além da forma da distribuição

df.describe()
# Out:
#        ID Passageiro  Sobrevivente      Classe  Valor da Passagem
# count     889.000000    889.000000  889.000000         889.000000
# mean      446.000000      0.382452    2.311586          32.096681
# std       256.998173      0.486260    0.834700          49.697504
# min         1.000000      0.000000    1.000000           0.000000
# 25%       224.000000      0.000000    2.000000           7.895800
# 50%       446.000000      0.000000    3.000000          14.454200
# 75%       668.000000      1.000000    3.000000          31.000000
# max       891.000000      1.000000    3.000000         512.329200

# %%
#Agrupar tipos de embarque
df[['Embarque']].value_counts()
# Out:
# Embarque
# S           644
# C           168
# Q            77
# dtype: int64

# %%
#SObreviventes por tipo de embarque
df[['Embarque']].value_counts()
# Out:
# Embarque
# S           644
# C           168
# Q            77
# dtype: int64

# %%
#SObreviventes por tipo de embarque
df[['Embarque', 'Sobrevivente']].value_counts()
# Out:
# Embarque  Sobrevivente
# S         0               427
#           1               217
# C         1                93
#           0                75
# Q         0                47
#           1                30
# dtype: int64

# %%
#Quantidade de individuos por sexo biológico
df[['Sexo Biológico']].value_counts()
# Out:
# Sexo Biológico
# male              577
# female            314
# dtype: int64

# %%
#Quantidade de sobreviventes e mortos
df[['Sobrevivente', 'Sexo Biológico']].value_counts()
# Out:
# Sobrevivente  Sexo Biológico
# 0             M                 468
# 1             F                 231
#               M                 109
# 0             F                  81
# dtype: int64

# %%
#Idade média dos passageiros
#Não consegui trabalhar com esse :(
df.groupby(['Sexo Biológico', 'Idade'])
print(df)
# Out:
#      ID Passageiro  Sobrevivente  Classe  \
# 0                1             0       3
# 1                2             1       1
# 2                3             1       3
# 3                4             1       1
# 4                5             0       3
# ..             ...           ...     ...
# 886            887             0       2
# 887            888             1       1
# 888            889             0       3
# 889            890             1       1
# 890            891             0       3
#
#                                         Nome/Sobrenome Sexo Biológico  Idade  \
# 0                              Braund, Mr. Owen Harris           male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         female   38.0
# 2                               Heikkinen, Miss. Laina         female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         female   35.0
# 4                             Allen, Mr. William Henry           male   35.0
# ..                                                 ...            ...    ...
# 886                              Montvila, Rev. Juozas           male   27.0
# 887                       Graham, Miss. Margaret Edith         female   19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"         female    NaN
# 889                              Behr, Mr. Karl Howell           male   26.0
# 890                                Dooley, Mr. Patrick           male   32.0
#
#      Sib  Passe          Passagem  Valor da Passagem Cabine Embarque
# 0      1      0         A/5 21171             7.2500    NaN        S
# 1      1      0          PC 17599            71.2833    C85        C
# 2      0      0  STON/O2. 3101282             7.9250    NaN        S
# 3      1      0            113803            53.1000   C123        S
# 4      0      0            373450             8.0500    NaN        S
# ..   ...    ...               ...                ...    ...      ...
# 886    0      0            211536            13.0000    NaN        S
# 887    0      0            112053            30.0000    B42        S
# 888    1      2        W./C. 6607            23.4500    NaN        S
# 889    0      0            111369            30.0000   C148        C
# 890    0      0            370376             7.7500    NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Conclusão
#
# A partir do tratamento e análise da base de dados foi possível observar que a maior parte dos sobreviventes fizeram o tipo de embarque S, este que também continha o maior número de integrantes, 644. Os passageiros do embarque C foram os mais atingidos com o total de 75 mortos de 93.
# Ademais. sobre a questão de sexo biológico, a maior parte dos passageiros era homens e  foram os que mais morreram, sendo 468 mortos de um total de 577 homens.
